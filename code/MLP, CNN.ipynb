# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
folder_path = f"/content/drive/MyDrive/"
df = pd.read_parquet(f"{folder_path}datasets/6month_avg/6month_avg_train.parquet")
# Out:
# Mounted at /content/drive

# %%
segment = df['Segment']
top100 = df[['이용금액_체크_R12M',
 '연체입금원금_B5M',
 '입회일자_신용',
 '이용금액_total_trend',
 '정상청구원금_B5M',
 '이용금액_일시불_R12M',
 '이용금액_오프라인_B0M',
 '이용금액_total',
 '월상환론한도금액_trend',
 '이용금액_일시불_R12M_trend',
 '월상환론한도금액',
 '평잔_일시불_6M',
 '최대이용금액_일시불_R12M_trend',
 '변동률_일시불평잔_trend',
 '정상청구원금_B2M',
 '이용금액_체크_R12M_trend',
 '이용금액_일시불_R6M',
 '정상청구원금_B5M_trend',
 '최대이용금액_체크_R12M',
 '연체입금원금_B0M',
 '연속유실적개월수_기본_24M_카드_trend',
 '증감율_이용금액_일시불_분기_trend',
 '평잔_일시불_6M_trend',
 '카드이용한도금액',
 '카드이용한도금액_B2M_trend',
 '연체입금원금_B2M',
 '연체입금원금_B0M_trend',
 '증감율_이용금액_일시불_전월_trend',
 '이용금액_오프라인_B0M_trend',
 '변동률_잔액_B1M_trend',
 '최대이용금액_일시불_R12M',
 '잔액_신판평균한도소진율_r6m_trend',
 '정상청구원금_B0M_trend',
 '최종이용일자_CA',
 '증감율_이용금액_신판_분기_trend',
 '최종카드발급경과월',
 '이용건수_일시불_R12M_trend',
 '연체입금원금_B5M_trend',
 '최대이용금액_체크_R12M_trend',
 '_1순위카드이용건수_trend',
 'CA이자율_할인전_trend',
 '이용건수_total_trend',
 '증감율_이용금액_신용_전월_trend',
 '컨택건수_이용유도_청구서_R6M_trend',
 '컨택건수_이용유도_EM_R6M_trend',
 '이용건수_일시불_R12M',
 '강제한도감액금액_R12M_trend',
 '정상청구원금_B0M',
 '증감율_이용금액_신용_분기_trend',
 'RV일시불이자율_할인전_trend',
 '입회경과개월수_신용',
 '변동률_잔액_일시불_B1M_trend',
 '컨택건수_이용유도_인터넷_R6M_trend',
 '이용후경과월_신판_trend',
 '이용후경과월_신용_trend',
 '_1순위카드이용금액_trend',
 '이용건수_total',
 '이용건수_신용_R12M_trend',
 '카드이용한도금액_trend',
 '_1순위카드이용건수',
 '연체입금원금_B2M_trend',
 '최종이용일자_할부',
 '정상청구원금_B2M_trend',
 'CA한도금액_trend',
 '평잔_6M',
 'CA한도금액',
 '이용금액대_01.100만원+_trend',
 'RV현금서비스이자율_할인전_trend',
 '일시상환론한도금액_trend',
 '이용건수_신용_R12M',
 '카드이용한도금액_B1M',
 '이용금액_일시불_R6M_trend',
 '증감율_이용건수_일시불_분기_trend',
 '카드이용한도금액_B1M_trend',
 '이용금액_오프라인_R6M',
 '할부금액_무이자_3M_R12M',
 '카드이용한도금액_B2M',
 '컨택건수_이용유도_LMS_R6M_trend',
 '상향가능한도금액_trend',
 '이용건수_일시불_R6M_trend',
 '이용금액_일시불_B0M',
 '잔액_신판ca평균한도소진율_r6m_trend',
 '최종이용일자_카드론',
 '최대이용금액_CA_R12M_trend',
 '이용금액_R3M_신용체크',
 '정상입금원금_B5M_trend',
 'CL이자율_할인전_trend',
 '컨택건수_이용유도_EM_R6M',
 '일시상환론한도금액',
 '정상입금원금_B5M',
 '청구금액_R6M_trend',
 '잔액_신판ca평균한도소진율_r3m_trend',
 '이용금액_부분무이자_R3M_trend',
 '증감율_이용건수_신용_분기_trend',
 '최대이용금액_CA_R12M',
 '이용금액_부분무이자_R6M_trend',
 '잔액_신판ca최대한도소진율_r3m_trend',
 '연속유실적개월수_기본_24M_카드',
 '변동률_할부평잔_trend',
 '최종이용일자_일시불']]

# %%
top100.to_csv('top100.csv', index=False)
segment.to_csv('segment.csv', index=False)

# %%
import pandas as pd
import numpy as np

top100 = pd.read_csv('top100.csv')
segment = pd.read_csv('segment.csv')

# %%
top100
# Out:
#         이용금액_체크_R12M  연체입금원금_B5M   입회일자_신용  이용금액_total_trend  정상청구원금_B5M  \
# 0               7695        3134  20130101     164172.171429       15813
# 1               -414         926  20170801      88380.585714        4279
# 2                179        9379  20080401     480953.357143       23354
# 3                324        7120  20160501     207413.600000       18865
# 4              13080           0  20180601      11360.000000          57
# ...              ...         ...       ...               ...         ...
# 399995         18627         181  20010701      18668.071429         181
# 399996          6110         318  20170701     175226.300000       24777
# 399997          2232        2690  20090501     123079.042857        9309
# 399998           686         346  20130101        523.600000         346
# 399999           430        2340  20180501      83723.114286        6560
#
#         이용금액_일시불_R12M  이용금액_오프라인_B0M  이용금액_total  월상환론한도금액_trend  \
# 0               23394           3934      165822        0.000000
# 1               54479           4040       87088    91662.028571
# 2               48858           7228      530051        0.000000
# 3               13673           4130      186924        0.000000
# 4               -1322              0       11758   155233.885714
# ...               ...            ...         ...             ...
# 399995              0              0       18627    54595.085714
# 399996         148882          10061      158953   156165.485714
# 399997          48545           5339      116247        0.000000
# 399998              0              0         686   180886.671429
# 399999          18411            756       81312        0.000000
#
#         이용금액_일시불_R12M_trend  ...  청구금액_R6M_trend  잔액_신판ca평균한도소진율_r3m_trend  \
# 0              22978.728571  ...    93413.285714                  0.788999
# 1              54121.300000  ...    18361.528571                  0.584954
# 2              54115.757143  ...   158186.542857                  0.696537
# 3              14420.214286  ...   124884.385714                  0.930998
# 4              -1277.871429  ...       97.557143                  0.002948
# ...                     ...  ...             ...                       ...
# 399995             0.000000  ...        0.000000                  0.007531
# 399996        165566.128571  ...   148164.671429                  0.102588
# 399997         47709.514286  ...    39035.228571                  0.135717
# 399998             0.000000  ...        0.000000                  0.005878
# 399999         18160.942857  ...    26843.928571                  0.023186
#
#         이용금액_부분무이자_R3M_trend  증감율_이용건수_신용_분기_trend  최대이용금액_CA_R12M  \
# 0                 -15.100000             -0.378385           11919
# 1                 -15.100000             -0.008666            3430
# 2                  64.628571             -0.015179           73690
# 3                  17.042857              0.189861           12731
# 4                 -71.200000             -0.228571               0
# ...                      ...                   ...             ...
# 399995              8.071429              0.000000               0
# 399996             10.428571             -0.437023               0
# 399997            -29.085714              0.084437               0
# 399998             -9.757143              0.000000               0
# 399999            -15.657143              0.007462               0
#
#         이용금액_부분무이자_R6M_trend  잔액_신판ca최대한도소진율_r3m_trend  연속유실적개월수_기본_24M_카드  \
# 0                  -3.442857                  0.855499                  15
# 1                  -6.528571                  0.704743                  13
# 2                  13.200000                  0.867541                   9
# 3                   7.100000                  1.044309                  11
# 4                 -70.857143                  0.002484                   0
# ...                      ...                       ...                 ...
# 399995              1.557143                  0.016096                   0
# 399996             -0.200000                  0.157224                  18
# 399997            -14.000000                  0.205598                  24
# 399998             -1.871429                  0.012850                   0
# 399999             -6.057143                  0.043225                   3
#
#         변동률_할부평잔_trend  최종이용일자_일시불
# 0             0.759927    20180967
# 1             0.903146    20180968
# 2             1.237989    20180963
# 3             0.951551    20180960
# 4             0.999998    20180644
# ...                ...         ...
# 399995        0.999998    20179215
# 399996        0.499999    20180968
# 399997        0.488297    20180975
# 399998        0.999998    20161224
# 399999        0.721146    20180814
#
# [400000 rows x 100 columns]

# %% [markdown]
# # MLP

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.cuda.amp import autocast, GradScaler

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pandas as pd

# 입력 데이터 (예시로 DataFrame 사용)
X = top100.values  # (400000, 100)
y = segment.values.ravel()  # (400000,)

# 라벨 인코딩: a~e → 0~4
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 데이터 정규화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 훈련/검증 데이터 분리
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# 텐서 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# 데이터 로더 구성
train_dataset = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = torch.utils.data.TensorDataset(X_val_tensor, y_val_tensor)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1024, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1024, shuffle=False)

# 모델 정의
class MLPClassifier(nn.Module):
    def __init__(self, input_size=100, num_classes=5):
        super(MLPClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# 학습 및 평가
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MLPClassifier().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 에폭 단위 학습 루프
for epoch in range(10):  # 에폭 수는 조정 가능
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")


from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# 전체 검증 데이터에 대해 예측 수행
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 평가 지표 계산
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix 시각화
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 세션 다운돼서 다음과 같이 학습함.
#
# 1. 배치 사이즈 축소 (256)
#
# 2. 모델 구조 축소 (128 → 64 → 32)
#
# 3. 혼합 정밀도 학습 (AMP)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.cuda.amp import autocast, GradScaler

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

import numpy as np
import matplotlib.pyplot as plt

# ---------------------
# 1. 데이터 전처리
# ---------------------

X = top100.values
y = segment.values.ravel()

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 정규화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# train/val 분리
X_train, X_val, y_train, y_val = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42
)

# 텐서 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# DataLoader 구성 (배치 사이즈 256)
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=256, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=256, shuffle=False)

# ---------------------
# 2. 모델 정의 (경량화)
# ---------------------

class MLPClassifier(nn.Module):
    def __init__(self, input_size=100, num_classes=5):
        super(MLPClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# ---------------------
# 3. 학습 준비
# ---------------------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MLPClassifier().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scaler = GradScaler()  # AMP용 스케일러

# ---------------------
# 4. 학습 루프 (AMP 적용)
# ---------------------

epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        with autocast():  # 혼합 정밀도
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")

# ---------------------
# 5. 평가 (accuracy, f1, confusion matrix)
# ---------------------

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        with autocast():  # 평가 시에도 사용 가능
            outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 지표 출력
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 그래도 안돼서 학습 데이터 셋 무작위로 10만개만 뽑음
#
# (여기서 원본 40만개 데이터에서 segment 비율 유지하면서)

# %%
# ---------------------
# 1. 데이터 전처리
# ---------------------

X = top100.values
y = segment.values.ravel()

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 전체 데이터에서 100,000개 무작위 샘플링
sample_idx = np.random.choice(len(X), size=100000, replace=False)
X_sample = X[sample_idx]
y_sample = y_encoded[sample_idx]

# 정규화
scaler = StandardScaler()
X_sample_scaled = scaler.fit_transform(X_sample)

# train/val 나누기
X_train, X_val, y_train, y_val = train_test_split(
    X_sample_scaled, y_sample, test_size=0.2, random_state=42
)

# 텐서 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# DataLoader 구성
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=256, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=256, shuffle=False)

# ---------------------
# 2. 모델 정의 (경량화)
# ---------------------

class MLPClassifier(nn.Module):
    def __init__(self, input_size=100, num_classes=5):
        super(MLPClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# ---------------------
# 3. 학습 준비
# ---------------------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MLPClassifier().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scaler = GradScaler()  # AMP용 스케일러

# ---------------------
# 4. 학습 루프 (AMP 적용)
# ---------------------

epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        with autocast():  # 혼합 정밀도
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")
# Out:
# <ipython-input-10-ece409db8b39>:67: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()  # AMP용 스케일러
# <ipython-input-10-ece409db8b39>:81: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():  # 혼합 정밀도
# Epoch 1/10, Loss: 107.6942
# Epoch 2/10, Loss: 75.7225
# Epoch 3/10, Loss: 70.4428
# Epoch 4/10, Loss: 67.8359
# Epoch 5/10, Loss: 64.7781
# Epoch 6/10, Loss: 63.4947
# Epoch 7/10, Loss: 61.7892
# Epoch 8/10, Loss: 60.4777
# Epoch 9/10, Loss: 59.0403
# Epoch 10/10, Loss: 58.1501

# %%
# ---------------------
# 5. 평가 (accuracy, f1, confusion matrix)
# ---------------------

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        with autocast():  # 평가 시에도 사용 가능
            outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 지표 출력
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-11-aca7306e5c03>:12: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():  # 평가 시에도 사용 가능
# Validation Accuracy: 0.9175
# F1 Score (Macro): 0.6049
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-aca7306e5c03> in <cell line: 0>()
#      26 cm = confusion_matrix(all_labels, all_preds)
#      27 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
# ---> 28 disp.plot(cmap=plt.cm.Blues, values_format='d')
#      29 plt.title("Confusion Matrix")
#      30 plt.xticks(rotation=45)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     183         if colorbar:
#     184             fig.colorbar(self.im_, ax=ax)
# --> 185         ax.set(
#     186             xticks=np.arange(n_classes),
#     187             yticks=np.arange(n_classes),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     144             return
#     145
# --> 146         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147         cls.set.__name__ = "set"
#     148         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1239         # Artist._update_set_signature_and_docstring() at the end of the
#    1240         # module.
# -> 1241         return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1242
#    1243     @contextlib.contextmanager
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1231         The lack of prenormalization is to maintain backcompatibility.
#    1232         """
# -> 1233         return self._update_props(
#    1234             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235             "{prop_name!r}")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1207                             errfmt.format(cls=type(self), prop_name=k),
#    1208                             name=k)
# -> 1209                     ret.append(func(v))
#    1210         if ret:
#    1211             self.pchanged()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2115             # remove all tick labels, so only error for > 0 labels
#    2116             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2117                 raise ValueError(
#    2118                     "The number of FixedLocator locations"
#    2119                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (5).

# %%
from sklearn.model_selection import train_test_split

# 원본 데이터
X = top100.values
y = segment.values.ravel()

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Stratified 샘플링: 전체 100,000개 샘플링
X_sample, _, y_sample, _ = train_test_split(
    X, y_encoded,
    train_size=100000,
    stratify=y_encoded,
    random_state=42
)

# 정규화
scaler = StandardScaler()
X_sample_scaled = scaler.fit_transform(X_sample)

# 다시 학습/검증 분할 (stratify 유지)
X_train, X_val, y_train, y_val = train_test_split(
    X_sample_scaled, y_sample,
    test_size=0.2,
    stratify=y_sample,
    random_state=42
)

# 텐서 변환
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# DataLoader
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=256, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=256, shuffle=False)

# ---------------------
# 2. 모델 정의 (경량화)
# ---------------------

class MLPClassifier(nn.Module):
    def __init__(self, input_size=100, num_classes=5):
        super(MLPClassifier, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# ---------------------
# 3. 학습 준비
# ---------------------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MLPClassifier().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scaler = GradScaler()  # AMP용 스케일러

# ---------------------
# 4. 학습 루프 (AMP 적용)
# ---------------------

epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        with autocast():  # 혼합 정밀도
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")
# Out:
# <ipython-input-12-00df61802df0>:72: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()  # AMP용 스케일러
# <ipython-input-12-00df61802df0>:86: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():  # 혼합 정밀도
# Epoch 1/10, Loss: 117.2740
# Epoch 2/10, Loss: 75.4646
# Epoch 3/10, Loss: 70.8288
# Epoch 4/10, Loss: 67.2380
# Epoch 5/10, Loss: 65.3520
# Epoch 6/10, Loss: 63.4920
# Epoch 7/10, Loss: 61.8842
# Epoch 8/10, Loss: 60.7067
# Epoch 9/10, Loss: 59.3081
# Epoch 10/10, Loss: 58.1797

# %%
# ---------------------
# 5. 평가 (accuracy, f1, confusion matrix)
# ---------------------

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        with autocast():  # 평가 시에도 사용 가능
            outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 지표 출력
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-aca7306e5c03>:12: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():  # 평가 시에도 사용 가능
# Validation Accuracy: 0.9260
# F1 Score (Macro): 0.5242

# %% [markdown]
# # 1D CNN

# %%
import torch

if torch.cuda.is_available():
    print("GPU is 연결됨:", torch.cuda.get_device_name(0))
else:
    print("GPU를 사용할 수 없습니다.")


import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("GPU 연결됨:", tf.config.list_physical_devices('GPU'))
else:
    print("GPU를 사용할 수 없습니다.")
# Out:
# GPU is 연결됨: Tesla T4
# GPU 연결됨: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.cuda.amp import autocast, GradScaler

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

import numpy as np
import matplotlib.pyplot as plt

# ---------------------
# 1. 데이터 준비 및 전처리
# ---------------------
X = top100.values
y = segment.values.ravel()

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 클래스 비율 유지하며 100,000개 샘플링
X_sample, _, y_sample, _ = train_test_split(
    X, y_encoded,
    train_size=100000,
    stratify=y_encoded,
    random_state=42
)

# 정규화
scaler = StandardScaler()
X_sample_scaled = scaler.fit_transform(X_sample)

# train/val 분리 (클래스 비율 유지)
X_train, X_val, y_train, y_val = train_test_split(
    X_sample_scaled, y_sample,
    test_size=0.2,
    stratify=y_sample,
    random_state=42
)

# 텐서 변환 및 채널 차원 추가 (Conv1D용)
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)  # (batch, 1, 100)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).unsqueeze(1)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# DataLoader
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=256, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=256, shuffle=False)

# ---------------------
# 2. 1D CNN 모델 정의
# ---------------------
class CNN1DClassifier(nn.Module):
    def __init__(self, input_length=100, num_classes=5):
        super(CNN1DClassifier, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(32)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.relu2 = nn.ReLU()

        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.relu2(self.bn2(self.conv2(x)))
        x = self.pool(x)           # (batch, 64, 1)
        x = x.squeeze(2)           # (batch, 64)
        x = self.fc(x)             # (batch, 5)
        return x

# ---------------------
# 3. 학습 설정
# ---------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN1DClassifier(input_length=100).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scaler = GradScaler()

# ---------------------
# 4. 학습 루프
# ---------------------
epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        with autocast():
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")

# ---------------------
# 5. 평가 및 결과 출력
# ---------------------
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        with autocast():
            outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 지표 출력
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds, labels=list(range(5)))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-15-be6060f80734>:87: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-15-be6060f80734>:100: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/10, Loss: 160.5670
# Epoch 2/10, Loss: 122.0544
# Epoch 3/10, Loss: 120.0657
# Epoch 4/10, Loss: 118.5965
# Epoch 5/10, Loss: 117.1102
# Epoch 6/10, Loss: 115.7836
# Epoch 7/10, Loss: 114.2701
# Epoch 8/10, Loss: 113.4901
# Epoch 9/10, Loss: 112.6393
# Epoch 10/10, Loss: 111.9028
# <ipython-input-15-be6060f80734>:121: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Validation Accuracy: 0.8641
# F1 Score (Macro): 0.4048

# %%
## 클래스 불균형 보정을 적용한 CNN 모델 전체 코드

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.cuda.amp import autocast, GradScaler

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight

import numpy as np
import matplotlib.pyplot as plt

# ---------------------
# 1. 데이터 준비 및 전처리
# ---------------------
X = top100.values
y = segment.values.ravel()

# 라벨 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 클래스 비율 유지하며 100,000개 샘플링
X_sample, _, y_sample, _ = train_test_split(
    X, y_encoded,
    train_size=100000,
    stratify=y_encoded,
    random_state=42
)

# 정규화
scaler = StandardScaler()
X_sample_scaled = scaler.fit_transform(X_sample)

# train/val 분리 (클래스 비율 유지)
X_train, X_val, y_train, y_val = train_test_split(
    X_sample_scaled, y_sample,
    test_size=0.2,
    stratify=y_sample,
    random_state=42
)

# 텐서 변환 및 Conv1D용 차원 추가
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).unsqueeze(1)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=256, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=256, shuffle=False)

# ---------------------
# 2. 1D CNN 모델 정의 (조금 확장)
# ---------------------
class CNN1DClassifier(nn.Module):
    def __init__(self, input_length=100, num_classes=5):
        super(CNN1DClassifier, self).__init__()
        self.conv1 = nn.Conv1d(1, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(32)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv1d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.relu2 = nn.ReLU()

        self.conv3 = nn.Conv1d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()

        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.relu2(self.bn2(self.conv2(x)))
        x = self.relu3(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = x.squeeze(2)
        x = self.fc(x)
        return x

# ---------------------
# 3. 학습 설정 (클래스 가중치 적용)
# ---------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNN1DClassifier().to(device)

# 클래스 가중치 계산
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_sample),
    y=y_sample
)
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001)
scaler = GradScaler()

# ---------------------
# 4. 학습 루프
# ---------------------
epochs = 10
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        with autocast():
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss:.4f}")

# ---------------------
# 5. 평가 및 결과 출력
# ---------------------
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in val_loader:
        X_batch = X_batch.to(device)
        with autocast():
            outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(y_batch.numpy())

# 평가 지표
accuracy = accuracy_score(all_labels, all_preds)
f1_macro = f1_score(all_labels, all_preds, average='macro')

print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

# Confusion Matrix 시각화
cm = confusion_matrix(all_labels, all_preds, labels=list(range(5)))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-18-f2f30f2735b0>:102: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-18-f2f30f2735b0>:115: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/10, Loss: 290.6834
# Epoch 2/10, Loss: 244.1194
# Epoch 3/10, Loss: 235.1626
# Epoch 4/10, Loss: 230.6784
# Epoch 5/10, Loss: 226.3037
# Epoch 6/10, Loss: 222.4272
# Epoch 7/10, Loss: 221.4879
# Epoch 8/10, Loss: 217.8728
# Epoch 9/10, Loss: 216.3881
# Epoch 10/10, Loss: 215.6722
# <ipython-input-18-f2f30f2735b0>:136: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Validation Accuracy: 0.7720
# F1 Score (Macro): 0.3932

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Flatten, Dense, Dropout

# 1. 특성과 라벨 분리
X = top100.values
y = segment.values

# 2. 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. reshape for 1D CNN: (samples, steps, channels)
# 여기서 steps = 특성 개수, channel = 1
X_reshaped = X_scaled.reshape(-1, X_scaled.shape[1], 1)

# 4. train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y, test_size=0.2, random_state=42, stratify=y
)

# 5. 1D CNN 모델 정의
model = Sequential([
    Conv1D(64, kernel_size=3, activation='relu', input_shape=(X_reshaped.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')  # 5개 클래스 (A~E)
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 6. 학습
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)

# 7. F1 macro 평가
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)
y_true = np.argmax(y_test, axis=1)

f1_macro = f1_score(y_true, y_pred, average='macro')
print(f"F1 Score (macro): {f1_macro:.4f}")
