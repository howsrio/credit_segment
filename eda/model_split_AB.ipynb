# %%
import gc
import os

import pandas as pd
import numpy as np

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, classification_report

random_state = 42

# %%
print(os.getcwd())
# Out:
# c:\Users\erich\Desktop\HYU\신용카드 고객 세그먼트 분류 공모전\eda

# %%
# A/B

# %% [markdown]
# ### 데이터셋 로드

# %%
# train_set 준비

months = [7, 8, 9, 10, 11, 12]

trains = []

drop_columns = [
    'ID',
    # 'index',
    '기준년월',
    # '상품관련면제카드수_B0M',
    # '임직원면제카드수_B0M',
    # '우수회원면제카드수_B0M',
    # '기타면제카드수_B0M',
    '카드신청건수',
    '이용금액_R3M_체크',
    '이용금액_R3M_체크_가족',
    '유효카드수_체크',
    '유효카드수_체크_가족',
    '이용가능카드수_체크',
    '이용가능카드수_체크_가족',
    '이용카드수_체크',
    '이용카드수_체크_가족',
    '연회비발생카드수_B0M',
    '연회비할인카드수_B0M',
    '기본연회비_B0M',
    '제휴연회비_B0M',
    '할인금액_기본연회비_B0M',
    '할인금액_제휴연회비_B0M',
    '청구금액_기본연회비_B0M',
    '청구금액_제휴연회비_B0M',
    # '캠페인접촉건수_R12M',
    # '캠페인접촉일수_R12M'
]

for month in months:
    # train = pd.read_parquet(f"../data/train/1.회원정보/2018{month:02}_train_회원정보.parquet")
    # test = pd.read_parquet(f"../data/test/1.회원정보/2018{month:02}_test_회원정보.parquet")
    # customers.append(pd.concat([train, test], ignore_index=True))
    
    temp = pd.read_parquet(f"../data/train_FE_ver/train/FE_2018{month:02}_train_0402.parquet")
    temp = temp[(temp['Segment'] == "A") | (temp['Segment'] == "B")]
    temp["Segment"] = temp["Segment"].map({"A" : 0, "B" : 1})
    # temp.drop([f"Segment_{a}" for a in "ABCDE"], axis=1, inplace=True)
    
    temp.drop(drop_columns, axis=1, inplace=True)

    trains.append(temp)
    
del temp
gc.collect()
# Out:
# 0

# %%
trains[0]
# Out:
#         남녀구분코드  연령  Segment  회원여부_이용가능  회원여부_이용가능_CA  회원여부_이용가능_카드론  소지여부_신용  \
# 2898         1  40        0          1             1              0        1
# 5253         2  50        0          1             1              1        1
# 8128         2  40        0          1             1              1        1
# 10808        1  40        0          1             1              1        1
# 14951        2  30        0          1             1              0        1
# ...        ...  ..      ...        ...           ...            ...      ...
# 376373       2  40        0          1             0              1        1
# 378479       1  50        0          1             1              1        1
# 390620       2  50        1          1             1              0        1
# 393027       1  40        0          1             1              1        1
# 393888       1  40        0          1             1              1        1
#
#         소지카드수_유효_신용  소지카드수_이용가능_신용   입회일자_신용  ...  가스/전기료  최종카드론이용경과월_bin  \
# 2898              1              1  20070801  ...       0               1
# 5253              2              2  19930701  ...       0               1
# 8128              3              3  20110101  ...       0               0
# 10808             3              3  20001001  ...       0               0
# 14951             1              1  20130701  ...       0               0
# ...             ...            ...       ...  ...     ...             ...
# 376373            1              1  19970501  ...       0               0
# 378479            3              3  20030601  ...       0               0
# 390620            1              1  20000701  ...       0               1
# 393027            2              2  20021101  ...       0               0
# 393888            1              1  20150801  ...       0               0
#
#         최초카드론이용경과월_bin  카드론이용경과월_diff  카드이용한도금액_B1M_bin  이용금액_CA_R12M_bin  \
# 2898                 1            -20                 1                 1
# 5253                 1           -293                 1                 1
# 8128                 0              0                 1                 0
# 10808                0              0                 1                 0
# 14951                0              0                 1                 0
# ...                ...            ...               ...               ...
# 376373               0              0                 1                 0
# 378479               0              0                 1                 0
# 390620               1            -49                 0                 1
# 393027               0              0                 1                 0
# 393888               0              0                 1                 0
#
#         이용금액_R3M_신용_가족_bin  카드이용한도금액_cat  이용금액_CA_R3M_bin  할부건수_6M_R12M_bin
# 2898                     0             2                1                 1
# 5253                     0             2                1                 0
# 8128                     0             2                0                 1
# 10808                    1             2                0                 1
# 14951                    0             2                0                 1
# ...                    ...           ...              ...               ...
# 376373                   0             2                0                 0
# 378479                   1             2                0                 0
# 390620                   0             0                1                 0
# 393027                   0             2                0                 0
# 393888                   0             2                0                 0
#
# [186 rows x 928 columns]

# %% [markdown]
# ### 결측치 처리

# %%
missing_columns = trains[0].columns[trains[0].isna().any()]
missing_columns
# Out:
# Index([], dtype='object')

# %%
problematic_cols = []

for idx in range(len(trains)):
    for col in missing_columns:
        if col not in ['Segment']:
            for segment_label in trains[idx]['Segment'].unique():
                segment_values = trains[idx][trains[idx]['Segment'] == segment_label][col]
                if segment_values.isna().all():
                    print(f"⚠️  컬럼 '{col}'은 세그먼트 '{segment_label}'에서 모든 값이 결측치입니다.")
                    problematic_cols.append((col, segment_label))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay
import xgboost as xgb
import matplotlib.pyplot as plt


models = []
y_preds = []
idx = 7

importance_df = None  # 중요도 DataFrame 초기화

# 첫 번째 train으로 split 인덱스를 생성
first_train = trains[0]
X = first_train.drop("Segment", axis=1)
y = first_train["Segment"]
X_train_idx, X_test_idx = train_test_split(X.index, test_size=0.2, 
                                           random_state=42, stratify=y)

print("===== Macro F1 Score =====")

# 클래스 비율에 맞춰 scale_pos_weight 설정
# 다수 클래스: 162, 소수 클래스: 24
scale_pos_weight = 162 / 24

# 모든 train에 대해 동일한 index로 나누기
for train in trains:
    train_X = train.drop("Segment", axis=1)
    train_y = train["Segment"]

    X_train = train_X.loc[X_train_idx]
    X_test = train_X.loc[X_test_idx]
    y_train = train_y.loc[X_train_idx]
    y_test = train_y.loc[X_test_idx]

    # XGBoost 모델 생성 (클래스 가중치 적용)
    model = xgb.XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        use_label_encoder=False,
        random_state=random_state,
        scale_pos_weight=scale_pos_weight,  # 클래스 가중치 추가
        n_estimators=300,      # 트리 수 (부스팅 반복 횟수)
        learning_rate=0.1,     # 학습률
        max_depth=6           # 트리 최대 깊이
    )

    # 모델 학습
    model.fit(X_train, y_train,
              eval_set = [(X_test, y_test)],
              verbose = 50)

    # 예측
    y_pred = model.predict(X_test)
    y_preds.append(y_pred)

    # confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap='Blues')
    plt.title("Confusion Matrix")
    plt.show()

    # 중요도 추출
    score_dict = model.get_booster().get_score(importance_type='gain')
    score_series = pd.Series(score_dict, name=f'model_{idx - 6}_importance')

    if importance_df is None:
        # 첫 모델이면 기준 feature 목록 생성
        features = model.get_booster().feature_names
        importance_df = pd.DataFrame({'feature': features})

    # Series → DataFrame으로 변환 후 merge
    score_df = score_series.reset_index()
    score_df.columns = ['feature', f'month_{idx:02}_importance']
    
    importance_df = importance_df.merge(score_df, on='feature', how='left')

    models.append(model)

    # F1 점수 출력
    score = f1_score(y_test, y_pred, average='macro')
    print(f"{idx:02} : {round(score, 5)}")

    idx += 1

# NaN 값은 중요도 0으로 처리
importance_df.fillna(0, inplace=True)

# 중요도 총합 컬럼 추가 (선택)
importance_df['total_importance'] = importance_df.filter(like='month_').sum(axis=1)

# 정렬 (선택)
# importance_df.sort_values(by='total_importance', ascending=False, inplace=True)
# Out:
# ===== Macro F1 Score =====
# [0]	validation_0-logloss:0.61643
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:14] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.14020
# [100]	validation_0-logloss:0.11409
# [150]	validation_0-logloss:0.11197
# [200]	validation_0-logloss:0.11198
# [250]	validation_0-logloss:0.11198
# [299]	validation_0-logloss:0.11198
# 07 : 0.88485
# [0]	validation_0-logloss:0.61318
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:22] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.07537
# [100]	validation_0-logloss:0.05106
# [150]	validation_0-logloss:0.05112
# [200]	validation_0-logloss:0.05112
# [250]	validation_0-logloss:0.05112
# [299]	validation_0-logloss:0.05112
# 08 : 0.94685
# [0]	validation_0-logloss:0.60431
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:29] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.08364
# [100]	validation_0-logloss:0.05568
# [150]	validation_0-logloss:0.05441
# [200]	validation_0-logloss:0.05441
# [250]	validation_0-logloss:0.05441
# [299]	validation_0-logloss:0.05441
# 09 : 0.93698
# [0]	validation_0-logloss:0.60627
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:35] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.10591
# [100]	validation_0-logloss:0.10869
# [150]	validation_0-logloss:0.10850
# [200]	validation_0-logloss:0.10850
# [250]	validation_0-logloss:0.10850
# [299]	validation_0-logloss:0.10850
# 10 : 0.93698
# [0]	validation_0-logloss:0.60616
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:42] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.11591
# [100]	validation_0-logloss:0.11077
# [150]	validation_0-logloss:0.11156
# [200]	validation_0-logloss:0.11156
# [250]	validation_0-logloss:0.11156
# [299]	validation_0-logloss:0.11156
# 11 : 0.93698
# [0]	validation_0-logloss:0.62039
# c:\Users\erich\anaconda3\envs\CustomerSegment\lib\site-packages\xgboost\core.py:158: UserWarning: [16:02:50] WARNING: D:\bld\xgboost-split_1742444198260\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	validation_0-logloss:0.12235
# [100]	validation_0-logloss:0.10523
# [150]	validation_0-logloss:0.10276
# [200]	validation_0-logloss:0.10275
# [250]	validation_0-logloss:0.10275
# [299]	validation_0-logloss:0.10275
# 12 : 0.88485

# %%
importance_df.sort_values(by='total_importance', ascending=False, inplace=True)
importance_df.head(20)
# Out:
#                 feature  month_07_importance  month_08_importance  \
# 57               RV신청일자            26.154638            30.014217
# 343          최종카드론_대출금액             3.188777             0.000000
# 333          최초카드론이용경과월             0.000000            29.991598
# 773     증감율_이용건수_일시불_분기             0.000000            26.289534
# 340          최종카드론_대출일자             2.078734             2.666576
# 87           rv최초시작후경과일             4.060164             0.000000
# 49             카드이용한도금액             1.225523             1.345397
# 792  잔액_신판ca최대한도소진율_r3m             0.000000             0.000000
# 76         카드이용한도금액_B2M             0.569552             2.241159
# 75         카드이용한도금액_B1M             2.660586             0.781041
# 140       이용금액_카드론_R12M             1.462466             2.317449
# 12          동의여부_한도증액안내             5.218625             5.482945
# 571          월중평잔_RV일시불             0.000000             7.354366
# 50               CA한도금액             0.635728             2.466404
# 233           여유_공연이용금액             8.259121             0.000000
# 223         쇼핑_온라인_이용금액             1.101322             2.028536
# 91           최종이용일자_카드론             0.809500             0.864164
# 523         월중평잔_CA_B0M             0.000000             0.000000
# 920       카드론이용경과월_diff             0.000000             0.358477
# 785    잔액_신판평균한도소진율_r6m             0.000000             0.000000
#
#      month_09_importance  month_10_importance  month_11_importance  \
# 57             32.577190            26.009645            24.481482
# 343             9.675611             9.668018             9.668018
# 333             0.000000             0.000000             0.000000
# 773             0.000000             0.000000             0.000000
# 340             3.316737             3.693468             4.364147
# 87              2.574982             0.000000             0.000000
# 49              0.623298             2.348113             1.979090
# 792             0.000000             0.000000             0.000000
# 76              1.290324             0.000000             2.859767
# 75              0.085065             1.641792             2.790904
# 140             2.568255             4.692155             0.000000
# 12              0.000000             0.000000             0.000000
# 571             1.796194             0.000000             0.000000
# 50              1.984935             0.915039             1.300545
# 233             0.000000             0.000000             0.000000
# 223             0.000000             1.990762             3.055026
# 91              1.219927             1.408472             1.494508
# 523             0.000000             2.649866             0.000000
# 920             1.064189             2.306729             1.802851
# 785             0.000000             0.395373             0.000000
#
#      month_12_importance  total_importance
# 57             15.481849        154.719022
# 343             0.000000         32.200424
# 333             0.000000         29.991598
# 773             0.000000         26.289534
# 340             9.127144         25.246806
# 87             13.051838         19.686984
# 49              8.675108         16.196529
# 792            13.978616         13.978616
# 76              5.481970         12.442773
# 75              3.460443         11.419830
# 140             0.000000         11.040326
# 12              0.000000         10.701570
# 571             0.553653          9.704213
# 50              1.865499          9.168150
# 233             0.000000          8.259121
# 223             0.000000          8.175647
# 91              2.289195          8.085766
# 523             4.024143          6.674008
# 920             0.432564          5.964811
# 785             5.476694          5.872067

# %%
list(importance_df[importance_df["total_importance"] == 0]["feature"])
# Out:
# ['IB문의건수_분실도난_B0M',
#  'IB문의건수_SMS_B0M',
#  'IB문의건수_결제_B0M',
#  'IB문의건수_CA_B0M',
#  'IB문의건수_BL_B0M',
#  '연체잔액_B0M',
#  'IB문의건수_명세서_B0M',
#  'IB문의건수_APP_B0M',
#  'IB문의건수_부대서비스_B0M',
#  'IB문의건수_비밀번호_B0M',
#  'IB문의건수_할부_B0M',
#  'IB문의건수_정보변경_B0M',
#  'IB문의건수_결제일변경_B0M',
#  '연체잔액_카드론_B0M',
#  'IB문의건수_카드발급_B0M',
#  '연체잔액_할부_B0M',
#  '연체잔액_현금서비스_B0M',
#  'IB문의건수_포인트_B0M',
#  '연체잔액_일시불_B0M',
#  '월중평잔_할부',
#  'IB문의건수_CL_RV_B0M',
#  '연체일자_B0M',
#  'IB문의건수_APP_R6M',
#  'IB문의건수_부대서비스_R6M',
#  'IB문의건수_포인트_R6M',
#  'IB문의건수_카드발급_R6M',
#  'IB문의건수_BL_R6M',
#  'IB문의건수_분실도난_R6M',
#  'IB문의건수_CA_R6M',
#  'IB문의건수_CL_RV_R6M',
#  'IB문의건수_CS_R6M',
#  'IB상담건수_VOC_R6M',
#  'IB상담건수_VOC민원_R6M',
#  'IB상담건수_VOC불만_R6M',
#  'IB상담건수_금감원_R6M',
#  '불만제기건수_B0M',
#  '불만제기건수_R12M',
#  '불만제기후경과월_R12M',
#  '당사PAY_방문횟수_B0M',
#  '당사PAY_방문횟수_R6M',
#  '당사PAY_방문월수_R6M',
#  'IB문의건수_SMS_R6M',
#  'IB문의건수_비밀번호_R6M',
#  'IB문의건수_명세서_R6M',
#  '상담건수_R6M',
#  'IB문의건수_CS_B0M',
#  'IB상담건수_VOC_B0M',
#  '카드론잔액_최종경과월',
#  '월중평잔_할부_B0M',
#  '월중평잔_일시불_B0M',
#  'IB상담건수_VOC민원_B0M',
#  'IB문의건수_선결제_B0M',
#  'IB상담건수_금감원_B0M',
#  'IB문의건수_사용승인내역_R6M',
#  'IB문의건수_결제일변경_R6M',
#  '잔액_카드론_B0M',
#  'IB문의건수_한도_R6M',
#  'IB문의건수_선결제_R6M',
#  'IB문의건수_결제_R6M',
#  'IB문의건수_할부_R6M',
#  '잔액_리볼빙CA이월_B0M',
#  '잔액_리볼빙일시불이월_B0M',
#  'IB문의건수_정보변경_R6M',
#  'IB상담건수_VOC불만_B0M',
#  '잔액_현금서비스_B1M',
#  'IB문의건수_한도_B0M',
#  '인입일수_ARS_R6M',
#  '잔액_할부_유이자_B0M',
#  '평잔_CA_해외_6M',
#  'RV잔액이월횟수_R3M',
#  'RV잔액이월횟수_R6M',
#  'RV_최대잔액_R3M',
#  'RV_평균잔액_R3M',
#  '인입횟수_ARS_R6M',
#  '이용메뉴건수_ARS_R6M',
#  '인입월수_ARS_R6M',
#  '잔액_할부_해외_B0M',
#  '인입후경과월_ARS',
#  '인입횟수_ARS_B0M',
#  '이용메뉴건수_ARS_B0M',
#  '인입일수_ARS_B0M',
#  '방문횟수_PC_R6M',
#  '당사멤버쉽_방문횟수_R6M',
#  '방문횟수_앱_R6M',
#  'RV_최대잔액_R6M',
#  '평잔_CA_6M',
#  '평잔_할부_해외_6M',
#  'IB문의건수_사용승인내역_B0M',
#  '평잔_일시불_해외_3M',
#  '월중평잔',
#  '연체잔액_CA_해외_B0M',
#  '월중평잔_카드론',
#  '연체잔액_CA_B0M',
#  '연체잔액_할부_해외_B0M',
#  '연체잔액_RV일시불_해외_B0M',
#  '연체잔액_RV일시불_B0M',
#  '평잔_3M',
#  '평잔_RV일시불_3M',
#  '평잔_할부_6M',
#  '평잔_할부_해외_3M',
#  '평잔_CA_3M',
#  '평잔_CA_해외_3M',
#  '평잔_카드론_3M',
#  '평잔_6M',
#  '평잔_일시불_6M',
#  '평잔_일시불_해외_6M',
#  '연체잔액_일시불_해외_B0M',
#  'RV_평균잔액_R6M',
#  'RV_최대잔액_R12M',
#  '방문횟수_모바일웹_R6M',
#  '인입불만횟수_IB_R6M',
#  '잔액_카드론_B5M',
#  '잔액_카드론_B4M',
#  '이용메뉴건수_IB_R6M',
#  '인입후경과월_IB_R6M',
#  '인입횟수_IB_B0M',
#  '인입일수_IB_B0M',
#  '이용메뉴건수_IB_B0M',
#  '잔액_카드론_B3M',
#  '잔액_카드론_B2M',
#  '방문일수_모바일웹_R6M',
#  '잔액_카드론_B1M',
#  '월중평잔_일시불',
#  '인입불만일수_IB_R6M',
#  '인입불만월수_IB_R6M',
#  '인입불만후경과월_IB_R6M',
#  '인입불만횟수_IB_B0M',
#  '인입불만일수_IB_B0M',
#  '연체잔액_대환론_B0M',
#  '잔액_할부_B1M',
#  '인입월수_IB_R6M',
#  '연체일수_B1M',
#  '인입일수_IB_R6M',
#  '방문월수_모바일웹_R6M',
#  'RV_평균잔액_R12M',
#  '방문후경과월_모바일웹_R6M',
#  '방문횟수_PC_B0M',
#  '방문일수_PC_B0M',
#  '최종연체개월수_R15M',
#  '매각잔액_B1M',
#  '최종연체회차',
#  '연체원금_최근',
#  '연체일수_최근',
#  '연체원금_B2M',
#  '연체원금_B1M',
#  '방문횟수_모바일웹_B0M',
#  '방문일수_모바일웹_B0M',
#  '인입횟수_IB_R6M',
#  '인입횟수_금융_IB_R6M',
#  '연체일수_B2M',
#  '당사멤버쉽_방문횟수_B0M',
#  '컨택건수_카드론_EM_R6M',
#  '당사멤버쉽_방문월수_R6M',
#  '이용금액대_01.100만원+',
#  'LifeStage_독신',
#  'LifeStage_자녀독립기',
#  'LifeStage_자녀성장(1)',
#  'LifeStage_자녀성장(2)',
#  'LifeStage_자녀출산기',
#  '카드론신청경로_1',
#  '카드론신청경로_2',
#  '카드론신청경로_7',
#  '카드론신청경로_8',
#  '카드론신청경로_D',
#  '이용금액대_02.50만원+',
#  '거주_제주',
#  '이용금액대_03.30만원+',
#  '이용금액대_04.10만원+',
#  '이용금액대_05.10만원-',
#  '이용금액대_09.미사용',
#  '청구지_주거지',
#  '청구지_회사',
#  '수령지_K톡명세서+이메일',
#  '수령지_당사멤버십+이메일',
#  '수령지_당사페이앱+이메일',
#  '수령지_문자메세지',
#  'LifeStage_노년생활',
#  'LifeStage_가족구축기',
#  '신용체크2_체크',
#  '신용체크2_신용',
#  '거주_충북',
#  '직장_강원',
#  '직장_경기',
#  '직장_경남',
#  '직장_경북',
#  '직장_광주',
#  '직장_대구',
#  '직장_대전',
#  '직장_부산',
#  '직장_서울',
#  '직장_세종',
#  '직장_울산',
#  '직장_인천',
#  '직장_전남',
#  '직장_전북',
#  '직장_제주',
#  '직장_충남',
#  '직장_충북',
#  '거주직장일치',
#  '신용체크1_신용',
#  '신용체크1_체크',
#  '수령지_미수신',
#  '수령지_우편',
#  '수령지_이메일',
#  '택시',
#  '버스지하철',
#  '철도버스',
#  '통행료',
#  '여유기타',
#  '운동',
#  'Pet',
#  '항공',
#  '숙박',
#  '공원',
#  '보험료',
#  '통신비',
#  '관리비',
#  '납부기타',
#  '가스/전기료',
#  '최종카드론이용경과월_bin',
#  '최초카드론이용경과월_bin',
#  '카드이용한도금액_B1M_bin',
#  '이용금액_CA_R12M_bin',
#  '이용금액_R3M_신용_가족_bin',
#  '카드이용한도금액_cat',
#  '이용금액_CA_R3M_bin',
#  '주유',
#  '아울렛',
#  '청구지수령_K톡',
#  '백화점',
#  '청구지수령_당사멤버십',
#  '청구지수령_문자메세지',
#  '청구지수령_미수령',
#  '청구지수령_우편',
#  '청구지수령_이메일',
#  'OS_Android',
#  'OS_IOS',
#  '납부',
#  '쇼핑',
#  '사교활동',
#  '교육',
#  '교통',
#  '해외',
#  '여유생활',
#  '일상생활',
#  '요식',
#  '쇼핑기타',
#  '도소매',
#  '온라인',
#  '마트',
#  '편의점',
#  '거주_충남',
#  '거주_전북',
#  '홈페이지_금융건수_R6M',
#  '컨택건수_부대서비스_TM_R6M',
#  '컨택건수_이용유도_인터넷_B0M',
#  '컨택건수_카드론_당사앱_B0M',
#  '컨택건수_CA_당사앱_B0M',
#  '컨택건수_리볼빙_당사앱_B0M',
#  '컨택건수_이용유도_당사앱_B0M',
#  '컨택건수_카드론_TM_R6M',
#  '컨택건수_CA_TM_R6M',
#  '컨택건수_리볼빙_TM_R6M',
#  '컨택건수_이용유도_TM_R6M',
#  '컨택건수_신용발급_TM_R6M',
#  '컨택건수_포인트소진_TM_R6M',
#  '거주_전남',
#  '컨택건수_보험_TM_R6M',
#  '컨택건수_카드론_LMS_R6M',
#  '컨택건수_CA_LMS_R6M',
#  '컨택건수_리볼빙_LMS_R6M',
#  '포인트_마일리지_환산_B0M',
#  '컨택건수_CA_EM_R6M',
#  '컨택건수_리볼빙_EM_R6M',
#  '컨택건수_이용유도_EM_R6M',
#  '컨택건수_카드론_청구서_R6M',
#  '컨택건수_CA_청구서_R6M',
#  '컨택건수_리볼빙_인터넷_B0M',
#  '컨택건수_CA_인터넷_B0M',
#  '컨택건수_카드론_인터넷_B0M',
#  '컨택건수_이용유도_청구서_B0M',
#  '홈페이지_선결제건수_R6M',
#  '홈페이지_금융건수_R3M',
#  '홈페이지_선결제건수_R3M',
#  '컨택건수_카드론_TM_B0M',
#  '컨택건수_리볼빙_TM_B0M',
#  '컨택건수_CA_TM_B0M',
#  '컨택건수_이용유도_TM_B0M',
#  '컨택건수_신용발급_TM_B0M',
#  '컨택건수_부대서비스_TM_B0M',
#  '컨택건수_포인트소진_TM_B0M',
#  '컨택건수_보험_TM_B0M',
#  '컨택건수_카드론_LMS_B0M',
#  '컨택건수_CA_LMS_B0M',
#  '컨택건수_리볼빙_LMS_B0M',
#  '컨택건수_카드론_EM_B0M',
#  '컨택건수_CA_EM_B0M',
#  '컨택건수_리볼빙_EM_B0M',
#  '컨택건수_이용유도_EM_B0M',
#  '컨택건수_카드론_청구서_B0M',
#  '컨택건수_CA_청구서_B0M',
#  '컨택건수_리볼빙_청구서_B0M',
#  '컨택건수_리볼빙_청구서_R6M',
#  '컨택건수_카드론_인터넷_R6M',
#  '컨택건수_CA_인터넷_R6M',
#  '증감율_이용금액_체크_분기',
#  '잔액_신판ca최대한도소진율_r6m',
#  '변동률_일시불평잔',
#  '변동률_할부평잔',
#  '변동률_CA평잔',
#  '변동률_RVCA평잔',
#  '변동률_카드론평잔',
#  '변동률_잔액_CA_B1M',
#  '통신사_K사',
#  '통신사_L사',
#  '통신사_S사',
#  '거주_강원',
#  '거주_경남',
#  '거주_경북',
#  '거주_광주',
#  '거주_대구',
#  '거주_대전',
#  '거주_부산',
#  '거주_서울',
#  '거주_세종',
#  '거주_울산',
#  '거주_인천',
#  '증감율_이용금액_카드론_분기',
#  '증감율_이용금액_일시불_분기',
#  '컨택건수_리볼빙_인터넷_R6M',
#  '증감율_이용금액_신판_분기',
#  '컨택건수_카드론_당사앱_R6M',
#  '컨택건수_CA_당사앱_R6M',
#  '컨택건수_리볼빙_당사앱_R6M',
#  '컨택건수_이용유도_당사앱_R6M',
#  '컨택건수_채권_B0M',
#  '컨택건수_FDS_B0M',
#  '컨택건수_채권_R6M',
#  '컨택건수_FDS_R6M',
#  '증감율_이용건수_일시불_전월',
#  '증감율_이용건수_할부_전월',
#  '증감율_이용건수_CA_전월',
#  '증감율_이용건수_체크_전월',
#  '증감율_이용건수_카드론_전월',
#  '증감율_이용금액_일시불_전월',
#  '증감율_이용금액_CA_전월',
#  '증감율_이용금액_체크_전월',
#  '증감율_이용금액_카드론_전월',
#  '증감율_이용건수_신용_분기',
#  '증감율_이용건수_신판_분기',
#  '증감율_이용건수_체크_분기',
#  '증감율_이용건수_카드론_분기',
#  '혜택수혜금액',
#  '신청건수_ATM_CA_R6M',
#  '혜택수혜금액_R3M',
#  '이용건수_할부_무이자_R3M',
#  '이용개월수_할부_유이자_R6M',
#  '이용개월수_할부_무이자_R6M',
#  '이용개월수_부분무이자_R6M',
#  '이용개월수_CA_R6M',
#  '이용개월수_체크_R6M',
#  '이용개월수_카드론_R6M',
#  '이용건수_신용_R3M',
#  '이용건수_신판_R3M',
#  '이용건수_일시불_R3M',
#  '이용건수_할부_유이자_R3M',
#  '이용건수_부분무이자_R3M',
#  '이용개월수_일시불_R6M',
#  '이용건수_CA_R3M',
#  '이용건수_체크_R3M',
#  '이용건수_카드론_R3M',
#  '이용금액_일시불_R3M',
#  '이용금액_할부_R3M',
#  '이용금액_할부_유이자_R3M',
#  '이용금액_부분무이자_R3M',
#  '이용금액_CA_R3M',
#  '이용금액_카드론_R3M',
#  '이용개월수_신용_R3M',
#  '이용개월수_할부_R6M',
#  '이용개월수_신판_R6M',
#  '이용개월수_일시불_R3M',
#  '이용건수_할부_R6M',
#  '이용개월수_할부_R12M',
#  '이용개월수_할부_유이자_R12M',
#  '이용개월수_할부_무이자_R12M',
#  '이용개월수_부분무이자_R12M',
#  '이용개월수_CA_R12M',
#  '이용개월수_체크_R12M',
#  '이용개월수_카드론_R12M',
#  '이용건수_신용_R6M',
#  '이용건수_신판_R6M',
#  '이용건수_일시불_R6M',
#  '이용건수_할부_유이자_R6M',
#  '이용개월수_신용_R6M',
#  '이용건수_할부_무이자_R6M',
#  '이용건수_부분무이자_R6M',
#  '이용건수_CA_R6M',
#  '이용건수_체크_R6M',
#  '이용건수_카드론_R6M',
#  '이용금액_일시불_R6M',
#  '이용금액_할부_유이자_R6M',
#  '이용금액_부분무이자_R6M',
#  '이용금액_체크_R6M',
#  '이용금액_카드론_R6M',
#  '이용개월수_신판_R3M',
#  '이용개월수_할부_R3M',
#  '할부건수_무이자_6M_R12M',
#  '할부건수_14M_R12M',
#  '납부_건강연금이용금액',
#  '납부_기타이용금액',
#  '_2순위업종_이용금액',
#  '_3순위업종_이용금액',
#  '_1순위쇼핑업종_이용금액',
#  '_1순위교통업종_이용금액',
#  '_3순위교통업종_이용금액',
#  '_1순위여유업종_이용금액',
#  '_3순위여유업종_이용금액',
#  '할부건수_12M_R12M',
#  '할부금액_3M_R12M',
#  '납부_가스전기료이용금액',
#  '할부금액_6M_R12M',
#  '할부금액_14M_R12M',
#  '할부건수_유이자_3M_R12M',
#  '할부건수_유이자_6M_R12M',
#  '할부건수_유이자_12M_R12M',
#  '할부건수_유이자_14M_R12M',
#  '할부금액_유이자_3M_R12M',
#  '할부금액_유이자_6M_R12M',
#  '할부금액_유이자_12M_R12M',
#  '할부금액_유이자_14M_R12M',
#  '납부_유선방송이용금액',
#  '납부_렌탈료이용금액',
#  '이용개월수_할부_유이자_R3M',
#  '쇼핑_기타_이용금액',
#  '이용개월수_할부_무이자_R3M',
#  '이용개월수_부분무이자_R3M',
#  '이용개월수_CA_R3M',
#  '이용개월수_체크_R3M',
#  '이용개월수_카드론_R3M',
#  '이용가맹점수',
#  '이용금액_해외',
#  '쇼핑_도소매_이용금액',
#  '쇼핑_백화점_이용금액',
#  '쇼핑_아울렛_이용금액',
#  '교통_정비이용금액',
#  '납부_관리비이용금액',
#  '교통_통행료이용금액',
#  '교통_택시이용금액',
#  '교통_철도버스이용금액',
#  '여유_운동이용금액',
#  '여유_Pet이용금액',
#  '여유_공원이용금액',
#  '여유_여행이용금액',
#  '여유_항공이용금액',
#  '여유_기타이용금액',
#  '납부_통신비이용금액',
#  '이용개월수_일시불_R12M',
#  '이용개월수_신판_R12M',
#  '이용개월수_신용_R12M',
#  '자발한도감액횟수_R12M',
#  '보유여부_해외겸용_신용_본인',
#  '이용가능여부_해외겸용_신용_본인',
#  '이용여부_3M_해외겸용_신용_본인',
#  '최종카드발급경과월',
#  '최초한도금액',
#  '일시상환론한도금액',
#  '월상환론한도금액',
#  'CA이자율_할인전',
#  'RV약정청구율',
#  'RV최소결제비율',
#  '자발한도감액금액_R12M',
#  '이용가능여부_해외겸용_본인',
#  '자발한도감액후경과월',
#  '강제한도감액횟수_R12M',
#  '강제한도감액금액_R12M',
#  '강제한도감액후경과월',
#  '한도증액횟수_R12M',
#  '한도증액금액_R12M',
#  '한도증액후경과월',
#  '상향가능한도금액',
#  '상향가능CA한도금액',
#  '카드론동의여부',
#  '이용여부_3M_해외겸용_본인',
#  '보유여부_해외겸용_본인',
#  '최대이용금액_카드론_R12M',
#  '수신거부여부_SMS',
#  '회원여부_이용가능',
#  '회원여부_이용가능_CA',
#  '소지여부_신용',
#  '소지카드수_유효_신용',
#  '소지카드수_이용가능_신용',
#  '입회경과개월수_신용',
#  '회원여부_연체',
#  '이용거절여부_카드론',
#  '수신거부여부_DM',
#  '수신거부여부_메일',
#  '탈회횟수_발급6개월이내',
#  '최종유효년월_신용_이용가능',
#  '탈회횟수_발급1년이내',
#  '마케팅동의여부',
#  '유효카드수_신용체크',
#  '유효카드수_신용_가족',
#  '이용가능카드수_신용체크',
#  '이용가능카드수_신용',
#  '이용가능카드수_신용_가족',
#  '이용카드수_신용체크',
#  '이용카드수_신용_가족',
#  '_2순위카드이용건수',
#  '월상환론상향가능한도금액',
#  'RV전환가능여부',
#  '일시불ONLY전환가능여부',
#  '이용건수_신용_R12M',
#  '이용금액_카드론_B0M',
#  '이용후경과월_신용',
#  '이용후경과월_신판',
#  '이용후경과월_일시불',
#  '이용후경과월_할부',
#  '이용후경과월_할부_무이자',
#  '이용후경과월_부분무이자',
#  '이용후경과월_CA',
#  '이용후경과월_체크',
#  '이용후경과월_카드론',
#  '이용건수_신판_R12M',
#  '특별한도보유여부_R3M',
#  '이용건수_할부_유이자_R12M',
#  '이용건수_부분무이자_R12M',
#  '이용건수_CA_R12M',
#  '이용건수_체크_R12M',
#  '이용건수_카드론_R12M',
#  '이용금액_할부_유이자_R12M',
#  '이용금액_부분무이자_R12M',
#  '최대이용금액_할부_무이자_R12M',
#  '최대이용금액_부분무이자_R12M',
#  '최대이용금액_체크_R12M',
#  '이용금액_체크_B0M',
#  '이용금액_CA_B0M',
#  '이용금액_부분무이자_B0M',
#  '이용금액_할부_유이자_B0M',
#  '연체감액여부_R3M',
#  '한도심사요청건수',
#  '한도요청거절건수',
#  '한도심사요청후경과월',
#  '한도심사거절후경과월',
#  '시장단기연체여부_R6M',
#  '시장단기연체여부_R3M',
#  '시장연체상환여부_R6M',
#  '시장연체상환여부_R3M',
#  '최종이용일자_기본',
#  '최종이용일자_신판',
#  '이용건수_신용_B0M',
#  '이용건수_신판_B0M',
#  '이용건수_일시불_B0M',
#  '이용건수_할부_B0M',
#  '이용건수_할부_유이자_B0M',
#  '이용건수_할부_무이자_B0M',
#  '이용건수_부분무이자_B0M',
#  '이용건수_CA_B0M',
#  '이용건수_체크_B0M',
#  '이용건수_카드론_B0M',
#  '할부건수_무이자_3M_R12M',
#  '할부건수_무이자_12M_R12M',
#  '연체건수_R3M',
#  '이용금액_연체_B0M',
#  '이용금액_선결제_R3M',
#  '이용건수_선결제_R3M',
#  '이용횟수_선결제_B0M',
#  '이용금액_선결제_B0M',
#  '이용건수_선결제_B0M',
#  '이용횟수_연체_R6M',
#  '이용금액_연체_R6M',
#  '이용횟수_연체_R3M',
#  '이용금액_연체_R3M',
#  '이용횟수_연체_B0M',
#  '이용개월수_전체_R6M',
#  '이용건수_선결제_R6M',
#  '이용개월수_전체_R3M',
#  '이용개월수_결제일_R6M',
#  '이용개월수_결제일_R3M',
#  '선입금원금_B0M',
#  '정상입금원금_B0M',
#  '연체입금원금_B0M',
#  '정상청구원금_B2M',
#  '선입금원금_B2M',
#  '정상입금원금_B2M',
#  '연체입금원금_B2M',
#  '이용횟수_선결제_R3M',
#  '이용금액_선결제_R6M',
#  '선입금원금_B5M',
#  '이용금액_A페이_B0M',
#  '이용금액_D페이_R3M',
#  '이용건수_간편결제_R3M',
#  '이용건수_당사페이_R3M',
#  '이용건수_당사기타_R3M',
#  '이용건수_A페이_R3M',
#  '이용건수_B페이_R3M',
#  '이용건수_C페이_R3M',
#  '이용건수_D페이_R3M',
#  '이용금액_당사페이_B0M',
#  '이용금액_당사기타_B0M',
#  '이용금액_B페이_B0M',
#  '이용횟수_선결제_R6M',
#  '이용금액_C페이_B0M',
#  '이용금액_D페이_B0M',
#  '이용건수_간편결제_B0M',
#  '이용건수_당사페이_B0M',
#  '이용건수_당사기타_B0M',
#  '이용건수_A페이_B0M',
#  '이용건수_B페이_B0M',
#  '이용건수_C페이_B0M',
#  '이용건수_D페이_B0M',
#  '이용개월수_선결제_R6M',
#  '정상청구원금_B5M',
#  '정상입금원금_B5M',
#  '할부건수_무이자_14M_R12M',
#  '마일_적립포인트_R3M',
#  '포인트_마일리지_건별_R3M',
#  '포인트_마일리지_월적립_B0M',
#  '포인트_마일리지_월적립_R3M',
#  '포인트_포인트_월적립_B0M',
#  '포인트_포인트_월적립_R3M',
#  '포인트_적립포인트_R12M',
#  '포인트_적립포인트_R3M',
#  '포인트_이용포인트_R3M',
#  '포인트_잔여포인트_B0M',
#  '마일_적립포인트_R12M',
#  '마일_이용포인트_R12M',
#  '청구금액_R6M',
#  '마일_이용포인트_R3M',
#  '마일_잔여포인트_B0M',
#  '할인건수_B0M',
#  '할인금액_B0M',
#  '할인금액_청구서_R3M',
#  '할인금액_청구서_B0M',
#  '상환개월수_결제일_R3M',
#  '선결제건수_R6M',
#  '선결제건수_R3M',
#  '연체건수_R6M',
#  '포인트_마일리지_건별_B0M',
#  '청구금액_R3M',
#  '연체입금원금_B5M',
#  '승인거절건수_한도초과_B0M',
#  '건수_할부전환_R6M',
#  '건수_할부전환_R3M',
#  '금액_할부전환_R6M',
#  '금액_할부전환_R3M',
#  '연속무실적개월수_기본_24M_카드',
#  '연속유실적개월수_기본_24M_카드',
#  '신청건수_ATM_CA_B0',
#  '신청건수_ATM_CL_B0',
#  '신청건수_ATM_CL_R6M',
#  '승인거절건수_B0M',
#  '승인거절건수_BL_B0M',
#  '청구금액_B0',
#  '승인거절건수_입력오류_B0M',
#  '승인거절건수_기타_B0M',
#  '승인거절건수_R3M',
#  '승인거절건수_한도초과_R3M',
#  '승인거절건수_BL_R3M',
#  '승인거절건수_입력오류_R3M',
#  '승인거절건수_기타_R3M',
#  '청구서발송여부_B0',
#  '청구서발송여부_R3M',
#  '청구서발송여부_R6M',
#  '이용금액_C페이_R3M',
#  '이용금액_B페이_R3M',
#  '이용금액_A페이_R3M',
#  '증감_RP건수_전월',
#  'RP후경과월_아파트',
#  'RP후경과월_제휴사서비스직접판매',
#  'RP후경과월_렌탈',
#  'RP후경과월_가스',
#  'RP후경과월_전기',
#  'RP후경과월_보험',
#  'RP후경과월_학습비',
#  'RP후경과월_유선방송',
#  'RP후경과월_건강',
#  'RP후경과월_교통',
#  '증감_RP유형건수_전월',
#  'RP후경과월',
#  '증감_RP건수_통신_전월',
#  '증감_RP건수_아파트_전월',
#  '증감_RP건수_제휴사서비스직접판매_전월',
#  '증감_RP건수_렌탈_전월',
#  '증감_RP건수_가스_전월',
#  '증감_RP건수_전기_전월',
#  '증감_RP건수_보험_전월',
#  '증감_RP건수_학습비_전월',
#  '증감_RP건수_유선방송_전월',
#  '증감_RP건수_건강_전월',
#  'RP후경과월_통신',
#  'RP건수_교통_B0M',
#  '이용금액_당사기타_R3M',
#  '할부금액_부분_14M_R12M',
#  '할부금액_무이자_6M_R12M',
#  '할부금액_무이자_12M_R12M',
#  '할부금액_무이자_14M_R12M',
#  '할부건수_부분_3M_R12M',
#  '할부건수_부분_6M_R12M',
#  '할부건수_부분_12M_R12M',
#  '할부건수_부분_14M_R12M',
#  '할부금액_부분_3M_R12M',
#  '할부금액_부분_6M_R12M',
#  '할부금액_부분_12M_R12M',
#  'RP건수_B0M',
#  'RP건수_건강_B0M',
#  'RP유형건수_B0M',
#  'RP건수_통신_B0M',
#  'RP건수_아파트_B0M',
#  'RP건수_제휴사서비스직접판매_B0M',
#  'RP건수_렌탈_B0M',
#  'RP건수_가스_B0M',
#  'RP건수_전기_B0M',
#  'RP건수_보험_B0M',
#  'RP건수_학습비_B0M',
#  'RP건수_유선방송_B0M',
#  '증감_RP건수_교통_전월',
#  '최종카드론이용경과월',
#  '카드론이용월수_누적',
#  '이용금액_B페이_R6M',
#  '이용개월수_간편결제_R6M',
#  '이용개월수_당사페이_R6M',
#  '이용개월수_당사기타_R6M',
#  '이용개월수_A페이_R6M',
#  '이용개월수_B페이_R6M',
#  '이용개월수_C페이_R6M',
#  '이용개월수_D페이_R6M',
#  '이용금액_당사페이_R6M',
#  '이용금액_당사기타_R6M',
#  '이용금액_A페이_R6M',
#  '이용금액_C페이_R6M',
#  '카드론이용금액_누적',
#  '이용금액_D페이_R6M',
#  '이용건수_간편결제_R6M',
#  '이용건수_당사페이_R6M',
#  '이용건수_당사기타_R6M',
#  '이용건수_A페이_R6M',
#  '이용건수_B페이_R6M',
#  '이용건수_C페이_R6M',
#  '이용건수_D페이_R6M',
#  '이용금액_간편결제_R3M',
#  '이용금액_당사페이_R3M',
#  '이용건수_페이_오프라인_B0M',
#  '이용건수_페이_온라인_B0M',
#  '이용금액_페이_오프라인_B0M',
#  '이용건수_페이_오프라인_R3M',
#  '최종카드론_금융상환방식코드',
#  '최종카드론_대출월수',
#  '최종카드론_거치개월수',
#  '이용개월수_온라인_R6M',
#  '이용개월수_오프라인_R6M',
#  '이용금액_오프라인_R6M',
#  '이용건수_온라인_R6M',
#  '이용건수_오프라인_R6M',
#  '이용금액_오프라인_R3M',
#  '이용건수_온라인_R3M',
#  '이용금액_오프라인_B0M',
#  '이용건수_온라인_B0M',
#  '이용건수_오프라인_B0M',
#  '이용개월수_페이_온라인_R6M',
#  '이용개월수_페이_오프라인_R6M',
#  '이용금액_페이_온라인_R6M',
#  '이용건수_페이_온라인_R6M',
#  '이용건수_페이_오프라인_R6M',
#  '이용금액_페이_온라인_R3M',
#  '이용금액_페이_오프라인_R3M',
#  '이용건수_페이_온라인_R3M',
#  '할부건수_6M_R12M_bin']

# %% [markdown]
# ### 앙상블

# %%
preds = []

for train, model in zip(trains, models):
    train_X = train.drop("Segment", axis=1)
    train_y = train["Segment"]

    X_train = train_X.loc[X_train_idx]
    X_test = train_X.loc[X_test_idx]
    y_train = train_y.loc[X_train_idx]
    y_test = train_y.loc[X_test_idx]

    pred = model.predict_proba(X_test)
    preds.append(pred)

    # 확률 평균
    ensemble_preds = np.mean(preds, axis=0)

    # 최종 클래스 예측
    final_preds = np.argmax(ensemble_preds, axis=1)

# %%
# confusion matrix 계산
cm = confusion_matrix(y_test, final_preds)

# 시각화
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # 색상은 보기 좋게 파란색 계열
plt.title("Confusion Matrix")
plt.show()

# %%
score = f1_score(y_test, final_preds, average='macro')
print(f"{idx:02} : {round(score, 5)}")
# Out:
# 13 : 0.93698
